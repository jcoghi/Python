# %% [markdown]
# # Formas de interromper um for
#
# ### 2 Opções:
#
# - break -> interrompe e finaliza o for
# - continue -> interrompe e vai para o próximo item do for

# %%
vendas = [100, 150, 1500, 2000, 120]

# %% [markdown]
# - Caso 1: Se todas as vendas forem acima da meta, a loja ganha bônus

# %%
meta = 110
for venda in vendas:
    if venda < meta:
        print('Sem bonus')
        break
    else:
        print('Ganha bonus')
# Out:
# Sem bonus

# %% [markdown]
# - Caso 2: Exiba quem bateu a meta

# %%
vendedores = ['João', 'Julia', 'Ana', 'José', 'Maria']
meta = 130

for venda in vendas:
    if venda < meta:
        continue
    indice = vendas.index(venda)
    print(f'{vendedores[vendas.index(venda)]} bateu a meta de {meta} vendendo {venda} unidade')
# Out:
# Julia bateu a meta de 130 vendendo 150 unidade
# Ana bateu a meta de 130 vendendo 1500 unidade
# José bateu a meta de 130 vendendo 2000 unidade
