# %%
print('Programa educado!')

nome = input('Por favor, digite teu nome: \n') # INPUT é comando de entrada de dados (sempre STR)

print('Olá {}, seja bem-vindx'.format(nome))
print(f'Olá {nome}, seja bem-vind@')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('texto')
print(variável)
print('Texto junto {variável}')

print('Texto junto {}'.format(variável))
print(f'Texto junto da {variável}')

lista = [(Joao, 123), (Pedro, 456)] => posso alterar, criar, deletar, fazer qq coisa

tipo_especial_lista = set(lista) => (1,2,3,5,6) = > esse aqui não

tupla = ()

dicionário = {chave:valor}

.keys() => a lista de chaves
.values() => a lista de valores

usuarios = {
    Joao: 123
    Pedro: 465
    Camyla: 3456
}

login = ['Joao', 'Pedro','Camyla']
senha = ['123', '456', '3456']

input('Login: ') Joao
input('Senha: ') 123
# Out:
# 4
