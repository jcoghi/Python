# %%
# !pip install keyboard
import keyboard

keyboard.press_and_release('ctrl + t')
# Out:
# ...
#      |████████████████████████████████| 58 kB 4.5 MB/s
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-284b28d688d7> in <module>()
#       2 import keyboard
#       3
# ----> 4 keyboard.press_and_release('ctrl + t')
#
# /usr/local/lib/python3.7/dist-packages/keyboard/__init__.py in send(hotkey, do_press, do_release)
#     377     _listener.is_replaying = True
#     378
# --> 379     parsed = parse_hotkey(hotkey)
#     380     for step in parsed:
#     381         if do_press:
#
# /usr/local/lib/python3.7/dist-packages/keyboard/__init__.py in parse_hotkey(hotkey)
#     356     for step in _re.split(r',\s?', hotkey):
#     357         keys = _re.split(r'\s?\+\s?', step)
# --> 358         steps.append(tuple(key_to_scan_codes(key) for key in keys))
#     359     return tuple(steps)
#     360
#
# ...
