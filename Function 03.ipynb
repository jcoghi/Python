# %% [markdown]
# # Argumentos/Parâmetros da Função
#
# ### Estrutura:

# %% [raw]
# def minha_funcao(parametro1, parametro2, parametro3):
#     return parametro1 + parametro2 + parametro3

# %% [markdown]
# - Exemplo: nosso famoso print

# %%
def nome_completo(nome, sobrenome):
    return nome + " " + sobrenome

nome = input('Entre com um nome: ')
sobrenome = input('Entre com um sobrenome: ')
print(nome_completo(nome, sobrenome))
# Out:
# Entre com um nome: João
# Entre com um sobrenome: Felipe
# João Felipe

# %% [markdown]
# - Só para mostrar o funcionamento, vamos criar uma função de soma

# %%
def entrar_numeros():
    num = []
    contador = int(input('Entre a quantidade de números a serem somados: '))
    
    for count in range(contador):
        entrada = int(input(f'Entre com o {count + 1}º número: '))
        num.append(entrada)
    soma = sum(num)
    return  soma


soma = entrar_numeros()
print(soma)
# Out:
# Entre a quantidade de números a serem somados: 3
# Entre com o 1º número: 2
# Entre com o 2º número: 3
# Entre com o 3º número: 1
# 6

# %% [markdown]
# - Vamos criar uma function com parâmetro
#
# Digamos que estamos criando um programa para categorizar os produtos de uma revendedora de bebidas.
#
# Cada produto tem um código. O tipo de produto é dado pelas 3 primeiras letras do código.
#
# Ex:<br>
# Vinho -> BEB12302<br>
# Cerveja -> BEB12043<br>
# Vodka -> BEB34501<br>
#
# Guaraná -> BSA11104<br>
# Coca -> BSA54301<br>
# Sprite -> BSA34012<br>
# Água -> BSA09871<br>
#
# Repare que bebidas não alcóolicas começam com BSA e bebidas alcoolicas começam com BEB.
#
# Crie um programa que analise uma lista de produtos e envie instruções para a equipe de estoque dizendo quais produtos devem ser enviados para a área de bebidas alcóolicas.

# %%
def catalogar_produtos(lista_produtos):
    for n in range(len(lista_produtos)):
        lista_produtos[n].strip()
        lista_produtos[n] = lista_produtos[n].upper()

    lista_produtos.sort()

    for i,nome in enumerate(lista_produtos):
        if 'beb' in nome.casefold():
            print(f'Enviar produto {nome} para bebidas alcoólicas')
        else:
            print(f'Enviar produto {nome} para bebidas não alcoólicas')


produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']

catalogar_produtos(produtos)
# Out:
# Enviar produto BEB15385 para bebidas alcoólicas
# Enviar produto BEB19495 para bebidas alcoólicas
# Enviar produto BEB21365 para bebidas alcoólicas
# Enviar produto BEB24213 para bebidas alcoólicas
# Enviar produto BEB31623 para bebidas alcoólicas
# Enviar produto BEB46275 para bebidas alcoólicas
# Enviar produto BEB48898 para bebidas alcoólicas
# Enviar produto BEB56262 para bebidas alcoólicas
# Enviar produto BEB62362 para bebidas alcoólicas
# Enviar produto BEB73344 para bebidas alcoólicas
# Enviar produto BEB75073 para bebidas alcoólicas
# Enviar produto BEB79496 para bebidas alcoólicas
# Enviar produto BEB80694 para bebidas alcoólicas
# Enviar produto BEB85146 para bebidas alcoólicas
# Enviar produto BEB97471 para bebidas alcoólicas
# Enviar produto BSA11769 para bebidas não alcoólicas
# Enviar produto BSA33484 para bebidas não alcoólicas
# Enviar produto BSA45510 para bebidas não alcoólicas
# Enviar produto BSA59251 para bebidas não alcoólicas
# ...
