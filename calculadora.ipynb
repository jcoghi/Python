# %% [markdown]
# ## Vamos começar com variáveis
# _Variável:_ local da memória do computador que receberá um determinado valor de um determinado tipo
# ```
# String = 'texto'
# Inteiro = 10
# Float = 10.5
# Boolean = False/True
# ```
# <br>
# 🆕**REGRAS DE NOMES:**🆕<br>
# 1. Sempre letra minúscula<br>
# 2. Não utilizar acentuação<br>
# 3. Sem espaço para nome composto<br>

# %%
# Primeiro programa:
'''
Vamos fazer uma programa de somar dois números.
Usar num1, num2 e soma como variáveis. 
'''

# %% [markdown]
# ## Agora vamos ver como podemos inserir ou retirar informação do programa
# _input:_ Comando utilizado para inserir um **texto** <br>
# _print:_ Comando utilizado para imprimir alguma informação na tela
# ```
# nome = input('Entre com seu nome:')
# print('Programa educado')
# print = ("Olá {}, seja bem-vindo!".format(nome))
# ```

# %%
# Segundo programa:
'''
Desta vez o usuário deverá informar os dois números que serão somados.
Usar num1, num2 e soma como variáveis. 
'''

# %% [markdown]
# ## Condicional If, Elif e Else
# Para podermos trabalhar com diversas soluções possíveis, utilizamos a condicional **if**.<br><br>
# A estrutura para esta condicional é:
#
#
# ```
# if CONDIÇÃO 1:
#     O que o programa deve fazer caso a condição 1 seja satisfeita
#
# elif CONDIÇÃO 2:
#     O que o programa deve fazer caso a condição 1 seja satisfeita
#
# else:
#     O que o programa deve fazer caso a codição não seja satisfeita
# ```
# <br>
# **IMPORTANTE:** Devemos utilizar o *elif* sempre que temos mais do que uma condição para a solução do problema.

# %%
# Terceiro Programa:
'''
Crie um lista de opções para que o usuário selecione uma das opções:
1. Soma
2. Subtração
3. Multiplicação
4. Divisão
'''

# %%
# Agora vamos transformar isso em uma calculadora.
'''
Agora, o programa deve pedir ao usuário inserir 2 números,
selecionar qual a operação desejada.

O programa deve fazer o cálculo escolhido e informar ao usuário
seu resultado.
'''

# %% [markdown]
# ## Função
# Função é um trecho de código responsável por executar alguma tarefa específica.

# %%
# Vamos organizar nosso programa em fnuções: Soma, Subtracao, Multiplicacao e Divisão
'''
Nosso programa deve trabalhar com as funções agora.

Crie as funções citadas. Dentro destas funções, você deve colocar tudo o que 
fez para calcular e printar as operações.

Dentro das condições do if, você deve chamar a função para que ela funcione.
'''

# %%
num1 = input('Entre com o 1° número: ')
num1 = num1.replace(',','.')
num2 = input('Entre com o 2° número: ')
num2 = num2.replace(',','.')
opcao= input('''Entre com o número da opção desejada:
1. Soma
2. Subtração
3. Multiplicação
4. Divisão
''')

if opcao == '1':
    soma = float(num1) + float(num2)
    soma = str(soma).replace(".",",")
    print('A soma é {}'.format(soma))
elif opcao == '2':
    subtracao = float(num1) - float(num2)
    subtracao = str(subtracao).replace(".",",")
    print('A subtração é {}'.format(subtracao))
elif opcao == '3':
    multiplicacao = float(num1) * float(num2)
    multiplicacao = str(multiplicacao).replace(".",",")
    print('A multiplicação é {}'.format(multiplicacao))
elif opcao == '4':
    divisao = float(num1) / float(num2)
    divisao = str(divisao).replace(".",",")
    print('A divisão é {}'.format(divisao))
else:
    print('Erro, selecione uma opção válida!')

# %%
def Soma(num1, num2):
    soma = float(num1) + float(num2)
    soma = str(soma).replace(".",",")
    print('A soma é {}'.format(soma))

def Subtracao(num1, num2):
    subtracao = float(num1) - float(num2)
    subtracao = str(subtracao).replace(".",",")
    print('A subtração é {}'.format(subtracao))

def Multiplicacao(num1, num2):
    multiplicacao = float(num1) * float(num2)
    multiplicacao = str(multiplicacao).replace(".",",")
    print('A multiplicação é {}'.format(multiplicacao))

def Divisao (num1, num2):
    divisao = float(num1) / float(num2)
    divisao = str(divisao).replace(".",",")
    print('A divisão é {}'.format(divisao))


def Entrada():
    num1 = input('Entre com o 1° número: ')
    num1 = num1.replace(',','.')
    num2 = input('Entre com o 2° número: ')
    num2 = num2.replace(',','.')
    return (num1, num2)

Entrada()
opcao= input('''Entre com o número da opção desejada:
1. Soma
2. Subtração
3. Multiplicação
4. Divisão
''')

if opcao == '1':
    Soma(num1, num2)
elif opcao == '2':
    Subtracao(num1, num2)
elif opcao == '3':
    Multiplicacao(num1, num2)
elif opcao == '4':
   Divisao(num1, num2)
else:
    print('Erro, selecione uma opção válida!')
